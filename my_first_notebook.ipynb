# %% [markdown]
# **Hardware** refers to all physical components: CPU, RAM, GPU, keyboard, monitor, and mouse. These are the building blocks.
#
# **Software** refers to everything intangible: operating systems like Windows, macOS, and Linux; applications like Chrome, Zoom, and WhatsApp; and the code you will write throughout this course.
# The **Kernel** is the most critical component of the operating system. It sits between hardware and software
